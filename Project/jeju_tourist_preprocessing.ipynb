# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 한글 폰트 문제 해결 
# matplotlib은 한글 폰트를 지원하지 않음
# os정보
import platform

# font_manager : 폰트 관리 모듈
# rc : 폰트 변경 모듈
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

# unicode 설정
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic') # os가 macos
elif platform.system() == 'Windows':
    path = 'c:/Windows/Fonts/malgun.ttf' # os가 windows
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print("Unknown System")

# %%
# 2019.01~2022.11 제주 내국인 관광객 동별 추이
jeju_total = pd.read_csv("../JejuData/jeju_total.csv",index_col=0)
# jeju_total.head()

# %%
# 2019.01~2022.11 제주 외국인 관광객 동별 추이
jeju_foreigner = pd.read_csv("../JejuData/jeju_foreigner.csv",index_col=0)
# jeju_foreigner.head()
# jeju_foreigner.tail()

# %%
# 읍면동별 관광지 수 (통합 작업 필요)
jeju_attraction = pd.read_csv("../JejuData/jeju_attraction.csv")
jeju_attraction['읍면동'].unique()
jeju_attraction
# Out:
#        시   읍면동  관광지 수
# 0   서귀포시   강정동      6
# 1   서귀포시   남원읍     58
# 2   서귀포시   대정읍     65
# 3   서귀포시   대포동      7
# 4   서귀포시   도순동      3
# ..   ...   ...    ...
# 62   제주시   한림읍     64
# 63   제주시   해안동      3
# 64   제주시  화북이동      1
# 65   제주시  화북일동      2
# 66   제주시   회천동      3
#
# [67 rows x 3 columns]

# %%
# 2009.01~2019.12 도내 관광지 별 한국인/외국인 방문객 수
jeju_tour = pd.read_csv("../JejuData/jeju_tour.csv")
jeju_tour
# Out:
#         연도   월         관광지명    한국인    외국인
# 0     2009   1  (주)제주미니미니랜드  11484    234
# 1     2009   1      국립제주박물관  26913    513
# 2     2009   1        도립미술관      0      0
# 3     2009   1       만장굴관광지  32019   1648
# 4     2009   1          목석원   4169   2119
# ...    ...  ..          ...    ...    ...
# 6727  2019  12        카멜리아힐  64255  26897
# 6728  2019  12      테디베어뮤지엄      0      0
# 6729  2019  12        퍼시픽랜드      0      0
# 6730  2019  12       아쿠아플라넷  60363   5792
# 6731  2019  12          화락원      0      0
#
# [6732 rows x 5 columns]

# %%
card_2019 = pd.read_csv("../JejuData/제주특별자치도_주제1_제주 예비창업자를 위한 업종별 카드 매출과 매장수 데이터 활용_매쉬업결과_19.csv",encoding="euc-kr")
card_2019.head()
# Out:
#         년월   시도명 지역구분 읍면동명    업종코드       업종명 이용자 구분 관광구분   연령대  성별   이용금액  \
# 0  2019-01  서귀포시   도심  신효동  I56114  서양식 음식점업    내국인   단체  50.0  여성  11000
# 1  2019-01  서귀포시   도심  신효동  I56114  서양식 음식점업    내국인   단체  70.0  여성  60000
# 2  2019-01  서귀포시   도심  서홍동  I56114  서양식 음식점업    내국인   단체  60.0  여성  68000
# 3  2019-01  서귀포시   도심  신효동  I56114  서양식 음식점업    내국인   단체  40.0  여성  50000
# 4  2019-01  서귀포시   도심  월평동  I56114  서양식 음식점업    내국인   개별  50.0  남성  56000
#
#    매장수 업종명 대분류     데이터기준일자
# 0  646    음식점업  2020-12-15
# 1  646    음식점업  2020-12-15
# 2  646    음식점업  2020-12-15
# 3  646    음식점업  2020-12-15
# 4  646    음식점업  2020-12-15

# %%
card_2020 = pd.read_csv("../JejuData/제주특별자치도_주제1_제주 예비창업자를 위한 업종별 카드 매출과 매장수 데이터 활용_매쉬업결과_20.csv",encoding="euc-kr")
card_2020.head()
# Out:
#         년월  시도명 지역구분  읍면동명    업종코드  업종명 이용자 구분 관광구분   연령대    성별       이용금액  \
# 0  2020-01  제주시   도심    연동  I55112  여관업   기타외국   개별   NaN  알수없음     992658
# 1  2020-01  제주시   도심  아라일동  I55112  여관업   제주도민   도민  50.0    남성     190000
# 2  2020-01  제주시   도심    연동  I55112  여관업    내국인   단체  40.0    남성     250000
# 3  2020-01  제주시   도심    연동  I55112  여관업    내국인   단체  50.0    남성      60000
# 4  2020-01  제주시   도심    연동  I55112  여관업     법인   개별   NaN  알수없음  278474643
#
#     매장수 업종명 대분류     데이터기준일자
# 0  2057     숙박업  2020-12-15
# 1  2057     숙박업  2020-12-15
# 2  2057     숙박업  2020-12-15
# 3  2057     숙박업  2020-12-15
# 4  2057     숙박업  2020-12-15

# %%
card_2021 = pd.read_csv("../JejuData/제주특별자치도_주제1_제주 예비창업자를 위한 업종별 카드 매출과 매장수 데이터 활용_매쉬업결과_21.csv",encoding="euc-kr")
card_2021.head()
# Out:
#         년월  시도명 지역구분  읍면동명    업종코드  업종명 이용자 구분 관광구분   연령대    성별     이용금액  매장수  \
# 0  2021-01  제주시   도심  삼도일동  S96121  욕탕업     법인   단체   NaN  알수없음   160000   61
# 1  2021-01  제주시   읍면   한림읍  S96121  욕탕업    내국인   개별  70.0    남성    10000   61
# 2  2021-01  제주시   읍면   구좌읍  S96121  욕탕업   제주도민   도민  40.0    남성    15000   61
# 3  2021-01  제주시   도심  도두일동  S96121  욕탕업     법인   단체   NaN  알수없음    56000   61
# 4  2021-01  제주시   도심  삼도이동  S96121  욕탕업   제주도민   도민  70.0    남성  1154000   61
#
#   업종명 대분류     데이터기준일자
# 0    서비스업  2021-07-26
# 1    서비스업  2021-07-26
# 2    서비스업  2021-07-26
# 3    서비스업  2021-07-26
# 4    서비스업  2021-07-26

# %%
print(card_2019['업종명'].unique())
print(card_2020['업종명'].unique())
print(card_2021['업종명'].unique())
# Out:
# ['서양식 음식점업' '일식 음식점업' '비알콜 음료점업' '피자, 햄버거, 샌드위치 및 유사 음식점업' '기타 외국식 음식점업'
#  '여관업' '한식 음식점업' '휴양콘도 운영업' '중식 음식점업' '슈퍼마켓' '그외 기타 분류안된 오락관련 서비스업'
#  '기타 수상오락 서비스업' '여행사업' '내항 여객 운송업' '골프장 운영업' '면세점' '욕탕업' '기타 대형 종합 소매업'
#  '그외 기타 스포츠시설 운영업' '기타 주점업' '마사지업' '체인화 편의점' '관광 민예품 및 선물용품 소매업'
#  '건강보조식품 소매업' '일반유흥 주점업' '스포츠 및 레크레이션 용품 임대업' '전시 및 행사 대행업' '자동차 임대업'
#  '육류 소매업' '그외 기타 종합 소매업' '정기 항공 운송업' '기타 갬블링 및 베팅업' '화장품 및 방향제 소매업' '호텔업'
#  '빵 및 과자류 소매업' '차량용 주유소 운영업' '과실 및 채소 소매업' '차량용 가스 충전업' '기타음식료품위주종합소매업'
#  '수산물 소매업' '택시 운송업']
# ['여관업' '호텔업' '한식 음식점업' '관광 민예품 및 선물용품 소매업' '화장품 및 방향제 소매업' '차량용 가스 충전업'
#  '중식 음식점업' '빵 및 과자류 소매업' '과실 및 채소 소매업' '수산물 소매업' '차량용 주유소 운영업'
#  '건강보조식품 소매업' '기타 주점업' '스포츠 및 레크레이션 용품 임대업' '비알콜 음료점업' '전시 및 행사 대행업'
#  '여행사업' '자동차 임대업' '그외 기타 스포츠시설 운영업' '기타 대형 종합 소매업' '골프장 운영업'
#  '기타 수상오락 서비스업' '기타 갬블링 및 베팅업' '휴양콘도 운영업' '내항 여객 운송업' '택시 운송업'
#  '그외 기타 분류안된 오락관련 서비스업' '정기 항공 운송업' '욕탕업' '마사지업' '서양식 음식점업' '일식 음식점업'
# ...

# %%
# jeju_total.set_index("행정동명",inplace=True)

# %%
# jeju_foreigner.set_index("행정동명",inplace=True)

# %%
# jeju_total.to_csv("../JejuData/jeju_total.csv")
# jeju_foreigner.to_csv("../JejuData/jeju_foreigner.csv")

# %%
jeju_pop = pd.read_csv("../JejuData/202301_202301_주민등록인구및세대현황_월간.csv",encoding="euc-kr")
jeju_pop_2023_01 = jeju_pop[jeju_pop['행정구역'].str.contains('제주특별자치도')]

# %%
jeju_pop_2023_01.to_csv("../JejuData/jeju_pop_2023_01.csv")

# %%
jejusi_dong = ['일도일동','일도이동','이도일동','이도이동','삼도일동','삼도이동','용담일동','용담이동','건입동','화북동','삼양동','봉개동','아라동','오라동','연동','노형동','외도동','이호동','도두동']
jejusi_seobu = ['한림읍','애월읍','한경면']
jejusi_dongbu = ['조천읍','구좌읍']
seogwiposi_dong = ['송산동','정방동','중앙동','천지동','효돈동','영천동','동홍동','서홍동','대륜동','대천동','중문동','예래동']
seogwiposi_seobu = ['대정읍','안덕면']
seogwiposi_dongbu = ['남원읍','성산읍','표선면']
island = ['추자면','우도면']
jeju_area = ['일도일동','일도이동','이도일동','이도이동','삼도일동','삼도이동','용담일동','용담이동','건입동','화북동','삼양동','봉개동','아라동','오라동','연동','노형동','외도동','이호동','도두동','한림읍','애월읍','한경면','조천읍','구좌읍','송산동','정방동','중앙동','천지동','효돈동','영천동','동홍동','서홍동','대륜동','대천동','중문동','예래동','대정읍','안덕면','남원읍','성산읍','표선면','추자면','우도면']

# %%
# jeju_total, jeju_foreigner index 변경
jeju_total.index = jeju_total.index.str.replace('1','일')
jeju_total.index = jeju_total.index.str.replace('2','이')
jeju_foreigner.index = jeju_foreigner.index.str.replace('1','일')
jeju_foreigner.index = jeju_foreigner.index.str.replace('2','이')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 2
#       1 # jeju_total, jeju_foreigner index 변경
# ----> 2 jeju_total.index = jeju_total.index.str.replace('1','일')
#       3 jeju_total.index = jeju_total.index.str.replace('2','이')
#       4 jeju_foreigner.index = jeju_foreigner.index.str.replace('1','일')
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     179 if obj is None:
#     180     # we're accessing the attribute of the class, i.e., Dataset.geo
#     181     return self._accessor
# --> 182 accessor_obj = self._accessor(obj)
#     183 # Replace the property with the accessor object. Inspired by:
#     184 # https://www.pydanny.com/cached-property.html
#     185 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     186 # NDFrame
# ...

# %%
print(len(jeju_total.index))
print(len(jeju_foreigner.index))
print(len(jeju_area))
# Out:
# 43
# 43
# 43

# %% [markdown]
# ### 내국인 외국인 관광객 수 권역분류 col 추가

# %% [markdown]
# ### 행정동명으로 권역 컬럼 추가

# %%
jeju_total.reset_index(inplace=True)

# %%
jeju_total['권역'] = jeju_total['행정동명']

# %%
# 전체 관광객 권역 추가
jeju_total.loc[jeju_total['권역'].isin(jejusi_dong), '권역'] = '제주시 동권역'
jeju_total.loc[jeju_total['권역'].isin(jejusi_dongbu), '권역'] = '제주시 동부권역'
jeju_total.loc[jeju_total['권역'].isin(jejusi_seobu), '권역'] = '제주시 서부권역'
jeju_total.loc[jeju_total['권역'].isin(seogwiposi_dong), '권역'] = '서귀포시 동권역'
jeju_total.loc[jeju_total['권역'].isin(seogwiposi_dongbu), '권역'] = '서귀포시 동부권역'
jeju_total.loc[jeju_total['권역'].isin(seogwiposi_seobu), '권역'] = '서귀포시 서부권역'
jeju_total.loc[jeju_total['권역'].isin(island), '권역'] = '도서산간'

# %%
jeju_foreigner.reset_index(inplace=True)

# %%
jeju_foreigner['권역'] = jeju_foreigner['행정동명']

# %%
# 외국인 관광객 권역 추가
jeju_foreigner.loc[jeju_foreigner['권역'].isin(jejusi_dong), '권역'] = '제주시 동권역'
jeju_foreigner.loc[jeju_foreigner['권역'].isin(jejusi_dongbu), '권역'] = '제주시 동부권역'
jeju_foreigner.loc[jeju_foreigner['권역'].isin(jejusi_seobu), '권역'] = '제주시 서부권역'
jeju_foreigner.loc[jeju_foreigner['권역'].isin(seogwiposi_dong), '권역'] = '서귀포시 동권역'
jeju_foreigner.loc[jeju_foreigner['권역'].isin(seogwiposi_dongbu), '권역'] = '서귀포시 동부권역'
jeju_foreigner.loc[jeju_foreigner['권역'].isin(seogwiposi_seobu), '권역'] = '서귀포시 서부권역'
jeju_foreigner.loc[jeju_foreigner['권역'].isin(island), '권역'] = '도서산간'

# %%
jeju_total
# Out:
#     level_0  index  행정동명  2019년 01월  2019년 02월  2019년 03월  2019년 04월  \
# 0         0      0   건입동    128,123    115,266    132,868    141,119
# 1         1      1   구좌읍    399,817    373,998    439,812    491,809
# 2         2      2   남원읍    345,305    260,709    210,166    246,931
# 3         3      3   노형동    358,757    330,379    289,173    302,198
# 4         4      4   대륜동    227,123    203,367    225,811    245,878
# 5         5      5   대정읍    293,430    273,360    310,605    357,260
# 6         6      6   대천동    175,876    159,869    157,244    177,361
# 7         7      7   도두동    165,380    144,563    175,872    194,096
# 8         8      8   동홍동     84,315     82,988     68,939     70,881
# 9         9      9   봉개동    100,131     89,861    110,640    160,224
# 10       10     10  삼도일동     36,900     43,802     43,585     31,409
# 11       11     11  삼도이동    217,812    213,333    201,806    164,639
# 12       12     12   삼양동     38,148     45,212     34,597     34,556
# ...

# %%
jeju_foreigner.to_csv("../JejuData/jeju_foreigner.csv",index=False)
jeju_total.to_csv("../JejuData/jeju_total.csv",index=False)

# %%
jeju_foreigner
# Out:
#     index  행정동명 2019년 01월 2019년 02월 2019년 03월 2019년 04월 2019년 05월 2019년 06월  \
# 0       0   건입동     2,338     2,601     2,773     3,795     3,138     3,246
# 1       1   구좌읍     3,733     3,830     3,908     5,785     4,773     4,473
# 2       2   남원읍     3,474     5,179     3,009     2,672     3,489     3,964
# 3       3   노형동    17,511    18,470    20,662    25,260    26,260    24,932
# 4       4   대륜동     2,992     3,424     3,157     3,600     4,210     4,944
# 5       5   대정읍    10,795    12,055    14,071    16,025    17,363    14,676
# 6       6   대천동     2,902     2,880     3,522     3,353     4,160     4,115
# 7       7   도두동     4,212     4,482     5,133     6,412     6,716     7,387
# 8       8   동홍동     7,994     7,613     5,064     5,655     5,559     6,452
# 9       9   봉개동       983       632     1,084     1,613     1,339     1,103
# 10     10  삼도일동     4,283     5,813     5,068     6,647     6,232     5,792
# ...
