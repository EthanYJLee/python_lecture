# %%
import matplotlib.pyplot as plt
import pandas as pd
import folium
import numpy as np

# %%
plt.plot([2, 3, 5, 10,11,10,6,5,3])
plt.show()

# %%
x = np.arange(0, 2, 0.2)
plt.plot(x, x, 'r--', x, x**2, 'bo', x, x**3, 'g-.')
plt.xticks(np.arange(0,2,0.1))
plt.yticks(np.arange(1,7,1))
plt.axvline(1.0, 0, 1, color='lightgray', linestyle='--', linewidth=2)
plt.axvline(0.0, 0, 1, color='lightgray', linestyle='--', linewidth=2)
plt.axvline(1.8, 0, 1, color='lightgray', linestyle='--', linewidth=2)
plt.show()
